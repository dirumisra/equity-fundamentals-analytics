# %% [markdown]
# #### **Import libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### **Load the dataset (adjust filename if needed)**

# %%
# Path to the raw equity data CSV file
equity_data_path = "../../data/raw/equity_data.csv"

# Print the file path to verify that it's correct
print(equity_data_path)
# Out:
# ../../data/raw/equity_data.csv

# %% [markdown]
# **# Read the CSV file into a pandas DataFrame**

# %%
equity_df = pd.read_csv(equity_data_path)

equity_df
# Out:
#       S.No.                                      Industries              Name  \
# 0         1                       Auto Components Companies  Samvardh. Mothe.
# 1         2                       Auto Components Companies             Bosch
# 2         3                       Auto Components Companies         Uno Minda
# 3         4                       Auto Components Companies      Bharat Forge
# 4         5                       Auto Components Companies               MRF
# ...     ...                                             ...               ...
# 3140   3141  Chemicals & Petrochemicals (battery chemicals)  Energy InfrTrust
# 3141   3142  Chemicals & Petrochemicals (battery chemicals)  Confidence Petro
# 3142   3143  Chemicals & Petrochemicals (battery chemicals)        IRM Energy
# 3143   3144  Chemicals & Petrochemicals (battery chemicals)   Kotyark Indust.
# 3144   3145  Chemicals & Petrochemicals (battery chemicals)       Indifra Ltd
#
#         CMP Rs.  Mar Cap Rs.Cr.   Debt / Eq  Sales Rs.Cr.  Sales growth %  \
# 0        112.16        118389.50       0.53     117367.72            7.30
# 1      36870.00        108780.78       0.01      18959.70           10.55
# 2       1305.10         75253.94       0.46      18015.43           17.14
# 3       1446.20         69113.96       0.71      15268.83           -3.52
# 4     153355.00         65066.94       0.19      29130.05            9.56
# ...         ...              ...        ...           ...             ...
# 3140      87.45          5806.68       7.16       3876.27           -7.20
# 3141      40.54          1345.26       0.60       3717.08           37.24
# 3142     311.35          1274.33       0.08       1040.55           15.97
# 3143     242.15           248.91       0.54        238.66          -29.91
# 3144      16.15            11.77       0.00          4.77          -74.84
#
#       Sales Qtr Rs.Cr.  Profit growth %  Profit Var 5Yrs %  ROE %  OPM %  \
# 0             30172.97           -11.59              26.02  12.16   8.86
# 1              4794.80            13.42              12.76  15.55  13.11
# 2              4814.03            21.44              40.73  17.50  11.54
# 3              4031.93             3.89              20.51  11.58  17.66
# 4              7378.72            -4.82               5.75  10.62  14.11
# ...                ...              ...                ...    ...    ...
# 3140           1892.82           -68.79              15.31   0.46  38.24
# 3141            983.01            33.35              11.63   7.24   9.05
# 3142            259.44           -35.29              15.48   4.68   8.86
# 3143            147.32           -90.70                NaN   9.83  10.51
# 3144              2.60          -250.00             -34.02   0.06 -15.72
#
#       EPS 12M Rs.    PEG    P/E  PAT 12M Rs.Cr.  ROCE %  CMP / BV
# 0            3.10   0.59  35.35         3348.88   13.66      3.19
# 1          909.18   2.61  47.89         2271.53   21.11      7.76
# 2           19.02   1.74  68.82         1093.46   18.83     12.08
# 3           22.54  80.94  63.94         1080.93   12.18      7.39
# 4         4370.73   0.70  35.10         1853.67   13.62      3.35
# ...           ...    ...    ...             ...     ...       ...
# 3140         1.33  -0.88  65.53           88.61    4.20      6.42
# 3141         2.83  34.93  14.32           93.96    9.33      0.98
# 3142        10.00  -1.02  31.03           41.07    8.26      1.32
# 3143         2.65    NaN  91.51            2.72   13.03      1.67
# 3144        -0.53    NaN    NaN           -0.39    0.11      0.65
#
# [3145 rows x 19 columns]

# %% [markdown]
# **# Display the first 5 rows of the dataset.**

# %%
# We use .head() to quickly inspect the structure of the data
# and confirm that it loaded correctly.
equity_df.head()
# Out:
#    S.No.                 Industries              Name    CMP Rs.  \
# 0      1  Auto Components Companies  Samvardh. Mothe.     112.16
# 1      2  Auto Components Companies             Bosch   36870.00
# 2      3  Auto Components Companies         Uno Minda    1305.10
# 3      4  Auto Components Companies      Bharat Forge    1446.20
# 4      5  Auto Components Companies               MRF  153355.00
#
#    Mar Cap Rs.Cr.   Debt / Eq  Sales Rs.Cr.  Sales growth %  Sales Qtr Rs.Cr.  \
# 0        118389.50       0.53     117367.72            7.30          30172.97
# 1        108780.78       0.01      18959.70           10.55           4794.80
# 2         75253.94       0.46      18015.43           17.14           4814.03
# 3         69113.96       0.71      15268.83           -3.52           4031.93
# 4         65066.94       0.19      29130.05            9.56           7378.72
#
#    Profit growth %  Profit Var 5Yrs %  ROE %  OPM %  EPS 12M Rs.    PEG  \
# 0           -11.59              26.02  12.16   8.86         3.10   0.59
# 1            13.42              12.76  15.55  13.11       909.18   2.61
# 2            21.44              40.73  17.50  11.54        19.02   1.74
# 3             3.89              20.51  11.58  17.66        22.54  80.94
# 4            -4.82               5.75  10.62  14.11      4370.73   0.70
#
#      P/E  PAT 12M Rs.Cr.  ROCE %  CMP / BV
# 0  35.35         3348.88   13.66      3.19
# 1  47.89         2271.53   21.11      7.76
# 2  68.82         1093.46   18.83     12.08
# 3  63.94         1080.93   12.18      7.39
# 4  35.10         1853.67   13.62      3.35

# %% [markdown]
# **# Show the number of rows and columns in the DataFrame.**

# %%
# Show the number of rows and columns in the DataFrame.
# .shape helps understand the dataset size (e.g., how many records we have).
equity_df.shape
# Out:
# (3145, 19)

# %% [markdown]
# **# Display summary information about the DataFrame:**

# %%
# - column names
# - number of non-null values
# - data types
# - memory usage
# This helps identify missing data and understand the dataset's structure.
equity_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3145 entries, 0 to 3144
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              3145 non-null   int64
#  1   Industries         3145 non-null   object
#  2   Name               3145 non-null   object
#  3   CMP Rs.            3145 non-null   float64
#  4   Mar Cap Rs.Cr.     3145 non-null   float64
#  5   Debt / Eq          2971 non-null   float64
#  6   Sales Rs.Cr.       3143 non-null   float64
#  7   Sales growth %     2963 non-null   float64
#  8   Sales Qtr Rs.Cr.   3136 non-null   float64
#  9   Profit growth %    3088 non-null   float64
#  10  Profit Var 5Yrs %  2300 non-null   float64
#  11  ROE %              2920 non-null   float64
#  12  OPM %              2989 non-null   float64
#  13  EPS 12M Rs.        3127 non-null   float64
#  14  PEG                2258 non-null   float64
#  15  P/E                2506 non-null   float64
#  16  PAT 12M Rs.Cr.     3143 non-null   float64
#  17  ROCE %             3036 non-null   float64
#  18  CMP / BV           2921 non-null   float64
# dtypes: float64(16), int64(1), object(2)
# memory usage: 467.0+ KB
